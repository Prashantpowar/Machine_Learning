
# Out:
# ['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6']

# %%
dataset =pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
dataset['Diab']=diabetes.target

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6   Diab
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
#  10  Diab    442 non-null    float64
# dtypes: float64(11)
# memory usage: 38.1 KB

# %%
dataset.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.639623e-16  1.309912e-16 -8.013951e-16  1.289818e-16 -9.042540e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.301121e-16 -4.563971e-16  3.863174e-16 -3.848103e-16 -3.398488e-16
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.156131e-01 -1.023071e-01 -7.639450e-02 -1.260974e-01 -1.377672e-01
# 25%   -3.035840e-02 -3.511716e-02 -3.949338e-02 -3.324879e-02 -3.317903e-02
# 50%   -3.819065e-03 -6.584468e-03 -2.592262e-03 -1.947634e-03 -1.077698e-03
# 75%    2.984439e-02  2.931150e-02  3.430886e-02  3.243323e-02  2.791705e-02
# max    1.987880e-01  1.811791e-01  1.852344e-01  1.335990e-01  1.356118e-01
#
#              Diab
# count  442.000000
# mean   152.133484
# std     77.093005
# min     25.000000
# 25%     87.000000
# 50%    140.500000
# 75%    211.500000
# max    346.000000

# %%
##Check the missing values

# %%
dataset.isnull().sum()
# Out:
# age     0
# sex     0
# bmi     0
# bp      0
# s1      0
# s2      0
# s3      0
# s4      0
# s5      0
# s6      0
# Diab    0
# dtype: int64

# %%
dataset.corr()
# Out:
#            age       sex       bmi        bp        s1        s2        s3  \
# age   1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# sex   0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# bmi   0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# bp    0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# s1    0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# s2    0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# s3   -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# s4    0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# s5    0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# s6    0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
# Diab  0.187889  0.043062  0.586450  0.441484  0.212022  0.174054 -0.394789
#
#             s4        s5        s6      Diab
# age   0.203841  0.270777  0.301731  0.187889
# sex   0.332115  0.149918  0.208133  0.043062
# bmi   0.413807  0.446159  0.388680  0.586450
# bp    0.257653  0.393478  0.390429  0.441484
# s1    0.542207  0.515501  0.325717  0.212022
# s2    0.659817  0.318353  0.290600  0.174054
# s3   -0.738493 -0.398577 -0.273697 -0.394789
# s4    1.000000  0.617857  0.417212  0.430453
# s5    0.617857  1.000000  0.464670  0.565883
# s6    0.417212  0.464670  1.000000  0.382483
# Diab  0.430453  0.565883  0.382483  1.000000

# %%
import seaborn as sns

# %% [markdown]
# EDA

# %%
sns.pairplot(dataset)

# %%
sns.heatmap(dataset.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(dataset['age'], dataset['Diab'])
plt.xlabel("AGE")
plt.ylabel("DIAB")
# Out:
# Text(0, 0.5, 'DIAB')

# %%
plt.scatter(dataset['sex'], dataset['Diab'])

# %%
sns.regplot(x = 'age', y = 'Diab', data = dataset)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Diab'>

# %%
sns.regplot(x = 'sex', y = 'Diab', data = dataset)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='Diab'>

# %%
sns.regplot(x = 'bp', y = 'Diab', data = dataset)
# Out:
# <AxesSubplot:xlabel='bp', ylabel='Diab'>

# %%
sns.regplot(x = 'bmi', y = 'Diab', data = dataset)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='Diab'>

# %%
sns.boxplot(dataset['age'])
# Out:
# <AxesSubplot:>

# %%
dataset.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6   Diab
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
##independent and dependent features
x = dataset.iloc[:,:-1]
y = dataset.iloc[:,-1]

# %%
#
# [146 rows x 10 columns]

# %%
y_train
# Out:
# 87     134.0
# 211     70.0
# 309    142.0
# 206    196.0
# 247     51.0
#        ...
# 218    214.0
# 412    261.0
# 223    150.0
# 271    127.0
# 355     60.0
# Name: Diab, Length: 296, dtype: float64

# %%
y_test
# Out:
# 160     53.0
# 415    174.0
# 432    173.0
# 343    113.0
# 287    219.0
#        ...
# 438    104.0
# 113    297.0
# 269     87.0
# 108    232.0
# 33      87.0
# Name: Diab, Length: 146, dtype: float64

# %%
##standardize the dataset

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()

# %%
scalar
# Out:
# StandardScaler()

# %%
X_train = scalar.fit_transform(X_train)

# %%
X_test = scalar.transform(X_test)

# %%
X_test
# Out:
# array([[-0.19355515, -0.96676808, -1.32411994, ..., -0.84898869,
#         -0.77063888, -0.98525275],
#        [-0.11507251, -0.96676808,  0.1592224 , ...,  1.43127855,
#          0.26428399,  0.06190996],
#        [ 0.19885803, -0.96676808,  1.12564242, ...,  0.44316275,
#          1.09936068,  2.24349894],
#        ...,
#        [ 0.19885803, -0.96676808, -0.69482319, ..., -1.60907777,
#         -0.2818645 , -0.81072564],
#        [ 0.43430593,  1.03437424,  0.92336846, ...,  0.51917166,
#          0.89329881,  0.84728199],
#        [ 0.66975383, -0.96676808, -1.07689622, ..., -1.60907777,
#         -0.40893381,  0.06190996]])

# %%
##Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
##print the coefficients and the intercept
print(regression.coef_)
# Out:
# [ -2.10838803  -9.63533599  27.31916449  16.63726444 -52.78809908
#   38.6598666    7.43067066   3.7430163   42.31247756   1.10727543]

# %%
print(regression.intercept_)
# Out:
# 156.90878378378378

# %%
reg_pred = regression.predict(X_test)

# %%
reg_pred
# Out:
# array([ 83.6788587 , 171.96038985, 217.00635918, 162.43872728,
#        148.39009546, 123.04505757, 196.95350388,  76.69782013,
#        149.34753021, 198.3506424 , 196.90931078, 134.45380526,
#        195.4245552 , 213.81874085, 177.04988053, 101.31733527,
#        257.18625207, 218.56706467, 111.24210485,  89.70193733,
#         65.05036201,  49.6114531 ,  32.00829017,  76.92346963,
#        185.58000348, 170.32202671, 114.33527565, 157.59489785,
#        230.59011711, 141.83684909, 176.51903989, 178.83422276,
#        159.10029315,  97.16149962, 135.47914067, 235.50115351,
#        103.68616278, 126.36829648, 115.73880363, 160.15431052,
#        164.07560425, 192.02088582, 162.31268685, 189.33652835,
#        183.23655455, 175.22996956, 218.01580125, 160.99225565,
#         59.83771447, 146.88905583, 201.92200448, 124.7904751 ,
#        156.83744887, 227.19673678, 129.96297907, 166.62401297,
#        104.19596571,  92.48404427, 194.00211287,  76.50792344,
#         88.29752635, 176.33269043, 215.48210129, 243.50389856,
#        119.12739495,  87.42325128, 183.65924965, 116.03997004,
#         76.4254709 , 108.03623881, 270.74671373,  97.35723179,
#        242.12431827, 127.54822752,  55.05998589, 150.93601221,
#        113.06894695, 218.0127642 , 181.86138981,  46.9818054 ,
#        270.08132903, 213.86007581, 188.34222325,  63.41926695,
#        105.91775201, 169.36682572, 170.41546964, 170.40784163,
#         81.94844629,  88.3215849 , 169.92829721, 248.1952824 ,
#         69.49535623, 135.00597297, 171.62517675, 134.99907861,
#        191.94961323, 125.40644191, 131.76578018, 124.4143473 ,
#        295.62084465, 131.39396384, 206.82586065,  90.96702664,
#        170.74813218,  56.77404891,  73.70323599, 194.78451717,
#        186.42996714, 134.24742765,  99.1693655 , 115.44942484,
#        155.18656794, 105.58046423, 224.1766337 , 201.01217907,
#        215.95594862,  92.62008738, 104.29225768,  85.82891054,
#         49.42329314, 164.76020735, 195.59285682, 126.43197768,
#        210.43968171, 121.37958209,  74.62492018,  82.75580843,
#        223.94878407, 162.10958873, 179.65053309, 141.87681916,
#        121.7479774 , 158.27983196, 118.33952662, 158.26526291,
#        166.49511422, 121.15481203, 172.49351015, 188.58374607,
#        266.00559156, 104.26942084, 210.90110974,  89.14137232,
#        234.47985149, 107.17268359])

# %%
##Assumptions of Linear Regression

# %%
plt.scatter(y_test,reg_pred)
plt.xlabel("test truth data")
plt.ylabel("test predicted data")
# Out:
# Text(0, 0.5, 'test predicted data')

# %%
##residuals

# %%
residuals = y_test - reg_pred

# %%
sns.displot(residuals, kind="kde")

# %%
##scatter plot with predictions and residuals
##uniform distribution
plt.scatter(reg_pred,residuals)

# %%
##performances metrix

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,reg_pred))
print(mean_absolute_error(y_test,reg_pred))
print(np.sqrt(mean_absolute_error(y_test,reg_pred)))
# Out:
# 3078.707315105052
# 44.984072849701974
# 6.7070166877459

# %%
#R2 square and adjusted Rsquare

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,reg_pred)
print(score)
# Out:
# 0.4620866188204923

# %%
##adjusted R square
##display adjusted R square

1-(1-score)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.42224118317756576

# %% [markdown]
# Ridge Regression

# %%
from sklearn.linear_model import Ridge
ridge = Ridge()

# %%
ridge.fit(X_train, y_train)
# Out:
# Ridge()

# %%
ridge_pred = ridge.predict(X_test)

# %%
print(ridge.coef_)
# Out:
# [ -2.01146994  -9.50256343  27.40046747  16.57548909 -38.75397575
#   27.33506167   1.5768744    2.31676847  36.6723149    1.2352697 ]

# %%
print(ridge.intercept_)
# Out:
# 156.90878378378378

# %%
plt.scatter(y_test,ridge_pred)
plt.xlabel('test truth data')
plt.ylabel('test predicted data')
# Out:
# Text(0, 0.5, 'test predicted data')

# %%
##Residuals

# %%
ridge_residuals = y_test - ridge_pred
ridge_residuals
# Out:
# 160   -31.270211
# 415     3.924589
# 432   -43.898927
# 343   -51.382029
# 287    70.517606
#          ...
# 438    -1.162393
# 113    86.629381
# 269    -0.348727
# 108    -0.715748
# 33    -17.494170
# Name: Diab, Length: 146, dtype: float64

# %%
##Normal distribution expected

# %%
sns.displot(ridge_residuals, kind = 'kde')

# %%
##Scatter plot with prediction and residuals
## If it is uniform distribution, model is good
plt.scatter(ridge_pred,ridge_residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,ridge_pred))
print(mean_absolute_error(y_test,ridge_pred))
print(np.sqrt(mean_absolute_error(y_test,ridge_pred)))
# Out:
# 3057.631029917925
# 44.88744241457549
# 6.6998091326974

# %%
#R2 square and adjusted Rsquare

# %%
from sklearn.metrics import r2_score
R_score_ridge = r2_score(y_test,ridge_pred)
print(R_score_ridge)
# Out:
# 0.4657690785892685

# %%
##adjusted R square
##display adjusted R square

1-(1-R_score_ridge)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.42619641774402917

# %% [markdown]
# Lasso Regression

# %%
from sklearn.linear_model import Lasso
lasso = Lasso()

# %%
lasso.fit(X_train, y_train)
# Out:
# Lasso()

# %%
lasso_pred = lasso.predict(X_test)

# %%
print(lasso.coef_)
# Out:
# [ -0.50253883  -7.63141318  27.9061914   15.2414026   -4.53513235
#   -0.         -10.54525279   0.          22.78956913   0.32343919]

# %%
print(lasso.intercept_)
# Out:
# 156.90878378378378

# %%
plt.scatter(y_test,lasso_pred)
plt.xlabel('test truth data')
plt.ylabel('test predicted data')
# Out:
# Text(0, 0.5, 'test predicted data')

# %%
##Residuals

# %%
lasso_residuals = y_test - lasso_pred
lasso_residuals
# Out:
# 160   -32.978244
# 415     8.924785
# 432   -40.748057
# 343   -52.838858
# 287    67.632512
#          ...
# 438    -5.297985
# 113    90.841515
# 269    -1.726718
# 108     5.995127
# 33    -13.225145
# Name: Diab, Length: 146, dtype: float64

# %%
##Normal distribution expected

# %%
sns.displot(lasso_residuals, kind = 'kde')

# %%
##Scatter plot with prediction and residuals
## If it is uniform distribution, model is good
plt.scatter(lasso_pred,lasso_residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,lasso_pred))
print(mean_absolute_error(y_test,lasso_pred))
print(np.sqrt(mean_absolute_error(y_test,lasso_pred)))
# Out:
# 3038.332008877144
# 44.78564409766671
# 6.692207714772959

# %%
##R2 square and Adjusted square

# %%
from sklearn.metrics import r2_score
R_score_lassso = r2_score(y_test,lasso_pred)
print(R_score_lassso)
# Out:
# 0.4691410138201908

# %%
##adjusted R square
##display adjusted R square

1-(1-R_score_lassso)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.4298181259550198

# %% [markdown]
# ElasticNet

# %%
from sklearn.linear_model import ElasticNet
elasticnet=ElasticNet()

# %%
elasticnet.fit(X_train, y_train)
# Out:
# ElasticNet()

# %%
elasticnet_pred = elasticnet.predict(X_test)

# %%
print(elasticnet.coef_)
# Out:
# [ 0.         -5.09465815 19.8965739  12.31730784 -0.24335668 -1.48813241
#  -8.48993609  3.88217299 15.01001536  3.94995634]

# %%
print(elasticnet.intercept_)
# Out:
# 156.90878378378378

# %%
plt.scatter(y_test,elasticnet_pred)
plt.xlabel('test truth data')
plt.ylabel('test predicted data')
# Out:
# Text(0, 0.5, 'test predicted data')

# %%
##Residuals

# %%
elasticnet_residuals = y_test - elasticnet_pred
elasticnet_residuals
# Out:
# 160   -43.349786
# 415     6.804006
# 432   -34.815543
# 343   -50.343050
# 287    61.711453
#          ...
# 438   -24.898404
# 113    92.901353
# 269   -10.810052
# 108    21.146253
# 33    -21.195755
# Name: Diab, Length: 146, dtype: float64

# %%
##normal distribution expected

# %%
sns.displot(elasticnet_residuals, kind = 'kde')

# %%
##Scatter plot with prediction and residuals
## If it is uniform distribution, model is good
plt.scatter(elasticnet_pred,elasticnet_residuals)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test,elasticnet_pred))
print(mean_absolute_error(y_test,elasticnet_pred))
print(np.sqrt(mean_absolute_error(y_test,elasticnet_pred)))
# Out:
# 3119.9798665388994
# 45.870311215463914
# 6.772762450836727

# %% [markdown]
# #R2 squared

# %%
from sklearn.metrics import r2_score
R_score_elasticnet = r2_score(y_test,elasticnet_pred)
print(R_score_elasticnet)
# Out:
# 0.4548754566607246

# %%
##adjusted R square
##display adjusted R square

1-(1-R_score_elasticnet)*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1)
# Out:
# 0.4144958608578152
